# %%
import pandas as pd

# %%
df = pd.read_csv("D:/FIAP/Engenharia de Machine Learning/Fase 1/Projeto1/tech_challenge/data/books.csv")

# %%
df.head(10)
# Out:
#                                                title    price availability  \
# 0                            It's Only the Himalayas  Â£45.17     In stock
# 1  Full Moon over Noahâs Ark: An Odyssey to Mou...  Â£49.43     In stock
# 2  See America: A Celebration of Our National Par...  Â£48.87     In stock
# 3  Vagabonding: An Uncommon Guide to the Art of L...  Â£36.94     In stock
# 4                               Under the Tuscan Sun  Â£37.33     In stock
# 5                                 A Summer In Europe  Â£44.34     In stock
# 6                           The Great Railway Bazaar  Â£30.54     In stock
# 7                   A Year in Provence (Provence #1)  Â£56.88     In stock
# 8  The Road to Little Dribbling: Adventures of an...  Â£23.21     In stock
# 9          Neither Here nor There: Travels in Europe  Â£38.95     In stock
#
#   rating category                                         image_path
# 0    Two   Travel  tech_challenge/data/images\27a53d0bb95bdd88288...
# ...

# %%
df["id"] = df.index + 1
df.head()
# Out:
#                                                title    price availability  \
# 0                            It's Only the Himalayas  Â£45.17     In stock
# 1  Full Moon over Noahâs Ark: An Odyssey to Mou...  Â£49.43     In stock
# 2  See America: A Celebration of Our National Par...  Â£48.87     In stock
# 3  Vagabonding: An Uncommon Guide to the Art of L...  Â£36.94     In stock
# 4                               Under the Tuscan Sun  Â£37.33     In stock
#
#   rating category                                         image_path  id
# 0    Two   Travel  tech_challenge/data/images\27a53d0bb95bdd88288...   1
# 1   Four   Travel  tech_challenge/data/images\57770cac1628f440763...   2
# 2  Three   Travel  tech_challenge/data/images\9a7e63f12829df4b43b...   3
# 3    Two   Travel  tech_challenge/data/images\d5bf0090470b0b8ea46...   4
# 4  Three   Travel  tech_challenge/data/images\98c2e95c5fd1a4e7cd5...   5

# %%
df.to_dict(orient="records")
# Out:
# [{'title': "It's Only the Himalayas",
#   'price': 'Â£45.17',
#   'availability': 'In stock',
#   'rating': 'Two',
#   'category': 'Travel',
#   'image_path': 'tech_challenge/data/images\\27a53d0bb95bdd88288eaf66c9230d7e.jpg',
#   'id': 1},
#  {'title': 'Full Moon over Noahâ\x80\x99s Ark: An Odyssey to Mount Ararat and Beyond',
#   'price': 'Â£49.43',
#   'availability': 'In stock',
#   'rating': 'Four',
#   'category': 'Travel',
#   'image_path': 'tech_challenge/data/images\\57770cac1628f4407636635f4b85e88c.jpg',
#   'id': 2},
#  {'title': 'See America: A Celebration of Our National Parks & Treasured Sites',
#   'price': 'Â£48.87',
#   'availability': 'In stock',
#   'rating': 'Three',
#   'category': 'Travel',
#   'image_path': 'tech_challenge/data/images\\9a7e63f12829df4b43b31d110bf3dc2e.jpg',
#   'id': 3},
#  {'title': 'Vagabonding: An Uncommon Guide to the Art of Long-Term World Travel',
#   'price': 'Â£36.94',
#   'availability': 'In stock',
#   'rating': 'Two',
# ...
